# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# 	Matplotlib is a Python library that allows you to create high-quality 2D and 3D plots, charts, and figures.
#     Matplotlib is used for data visualization purposes, enabling users to explore and present data in a visually appealing and informative manner.
#     1.Line Plot
#     2.Scatter Plot
#     3.Bar Plot
#     4.Histogram
#     5.Pie Chart

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot. Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x, y, c = 'b')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [markdown]
#     The subplot() function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to display multiple plots or charts in a single figure, making it easier to compare and analyze different visualizations simultaneously.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
plt.figure()
plt.subplot(221)
plt.plot(x1, y1)
plt.subplot(222)
plt.plot(x2, y2)
plt.subplot(223)
plt.plot(x3, y3)
plt.subplot(224)
plt.plot(x4, y4)

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
#     A bar plot, also known as a bar chart or bar graph, is a visualization that represents categorical data using rectangular bars. Each bar's length or height corresponds to the value or frequency of the corresponding category.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.figure(figsize=(5,3))
plt.bar(company, profit)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Bar Plot")
plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot. box1 = np.random.normal(100, 10, 200) box2 = np.random.normal(90, 20, 200)

# %% [markdown]
#     A box plot, also known as a box-and-whisker plot, is a statistical visualization that provides a summary of a dataset's distribution. It displays the distribution of numerical data through quartiles, showing the median, interquartile range (IQR), and potential outliers.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
plt.figure(figsize=(3, 3))
plt.boxplot([box1, box2])
plt.xticks([1, 2], ['Box 1', 'Box 2'])
plt.xlabel('Box')
plt.ylabel('Value')
plt.title('Box Plot Comparison')
plt.show()
